# %% [markdown]
# # Teste para obter base de dados com todos os livros do site
# ***Site:** [Books to scrape](https://books.toscrape.com/)*

# %% [markdown]
# ## Imports

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from urllib.parse import urljoin
from IPython.display import Image, display
from tqdm import tqdm
from word2number import w2n

# %% [markdown]
# ## Página inicial do site

# %%
url = "https://books.toscrape.com/"
response = requests.get(url)

if response.status_code == 200:
    html_content = response.text
    print('Página obtida com sucesso')
else:
    print(f"Erro ao acessar a página. Código de status: {response.status_code}")
# Out:
# Página obtida com sucesso

# %%
soup = BeautifulSoup(html_content, 'html.parser')

# %%
print(soup.title.string.strip())
# Out:
# All products | Books to Scrape - Sandbox

# %% [markdown]
# ## Obter nomes e links das categorias de livros

# %%
categories_links = {}

categories_soup = soup.find_all("a")

for cat in categories_soup:
    attr = list(cat.attrs.values())[0]

    if attr.startswith("catalogue/category"):
        categories_links[cat.get_text(strip = True)] = attr.replace('index.html', '')

categories_links.pop('Books')
print(f"Quantidade de categorias = {len(categories_links)}")
categories_links
# Out:
# Quantidade de categorias = 50
# {'Travel': 'catalogue/category/books/travel_2/',
#  'Mystery': 'catalogue/category/books/mystery_3/',
#  'Historical Fiction': 'catalogue/category/books/historical-fiction_4/',
#  'Sequential Art': 'catalogue/category/books/sequential-art_5/',
#  'Classics': 'catalogue/category/books/classics_6/',
#  'Philosophy': 'catalogue/category/books/philosophy_7/',
#  'Romance': 'catalogue/category/books/romance_8/',
#  'Womens Fiction': 'catalogue/category/books/womens-fiction_9/',
#  'Fiction': 'catalogue/category/books/fiction_10/',
#  'Childrens': 'catalogue/category/books/childrens_11/',
#  'Religion': 'catalogue/category/books/religion_12/',
#  'Nonfiction': 'catalogue/category/books/nonfiction_13/',
#  'Music': 'catalogue/category/books/music_14/',
#  'Default': 'catalogue/category/books/default_15/',
#  'Science Fiction': 'catalogue/category/books/science-fiction_16/',
#  'Sports and Games': 'catalogue/category/books/sports-and-games_17/',
#  'Add a comment': 'catalogue/category/books/add-a-comment_18/',
#  'Fantasy': 'catalogue/category/books/fantasy_19/',
#  'New Adult': 'catalogue/category/books/new-adult_20/',
#  'Young Adult': 'catalogue/category/books/young-adult_21/',
#  'Science': 'catalogue/category/books/science_22/',
#  'Poetry': 'catalogue/category/books/poetry_23/',
#  'Paranormal': 'catalogue/category/books/paranormal_24/',
#  'Art': 'catalogue/category/books/art_25/',
#  'Psychology': 'catalogue/category/books/psychology_26/',
#  'Autobiography': 'catalogue/category/books/autobiography_27/',
#  'Parenting': 'catalogue/category/books/parenting_28/',
#  'Adult Fiction': 'catalogue/category/books/adult-fiction_29/',
#  'Humor': 'catalogue/category/books/humor_30/',
#  'Horror': 'catalogue/category/books/horror_31/',
#  'History': 'catalogue/category/books/history_32/',
#  'Food and Drink': 'catalogue/category/books/food-and-drink_33/',
#  'Christian Fiction': 'catalogue/category/books/christian-fiction_34/',
#  'Business': 'catalogue/category/books/business_35/',
#  'Biography': 'catalogue/category/books/biography_36/',
#  'Thriller': 'catalogue/category/books/thriller_37/',
#  'Contemporary': 'catalogue/category/books/contemporary_38/',
#  'Spirituality': 'catalogue/category/books/spirituality_39/',
#  'Academic': 'catalogue/category/books/academic_40/',
#  'Self Help': 'catalogue/category/books/self-help_41/',
#  'Historical': 'catalogue/category/books/historical_42/',
#  'Christian': 'catalogue/category/books/christian_43/',
#  'Suspense': 'catalogue/category/books/suspense_44/',
#  'Short Stories': 'catalogue/category/books/short-stories_45/',
#  'Novels': 'catalogue/category/books/novels_46/',
#  'Health': 'catalogue/category/books/health_47/',
#  'Politics': 'catalogue/category/books/politics_48/',
#  'Cultural': 'catalogue/category/books/cultural_49/',
#  'Erotica': 'catalogue/category/books/erotica_50/',
#  'Crime': 'catalogue/category/books/crime_51/'}

# %% [markdown]
# ## Salvar as informações dos livros em um dataframe

# %%
base_livros = pd.DataFrame()

def get_books_attrs(url, cat):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    livros_soup = soup.find_all('article')
    dados = []

    for livro in livros_soup:
        title = livro.find('h3').find('a')['title']
        price = float(livro.find_all('p')[1].get_text().replace('Â£', ''))
        rating = int(w2n.word_to_num(livro.find('p')['class'][1].lower()))
        availability = livro.find_all('p')[2].get_text(strip=True)
        image = urljoin("https://books.toscrape.com/", livro.find('img')['src'])

        dados.append({
            'title': title,
            'price': price,
            'rating': rating,
            'availability': availability,
            'category': cat,
            'image': image
        })

    return pd.DataFrame(dados), soup

for cat, link in tqdm(categories_links.items()):
    # print(f'Categoria: {cat}')

    url_cat = url + link

    while True:
        tmp, soup_cat = get_books_attrs(url_cat, cat)
        base_livros = pd.concat([base_livros, tmp], ignore_index = True)

        next_button = soup_cat.find('li', class_ = 'next')

        if next_button:
            next_page = next_button.find('a')['href']
            url_cat = urljoin(url_cat, next_page)
        else:
            break
# Out:
# 100%|██████████| 50/50 [01:04<00:00,  1.29s/it]

# %%
print(f"Quantidade de livros: {base_livros.shape[0]}")
print(base_livros.dtypes)
base_livros.head()
# Out:
# Quantidade de livros: 1000
# title            object
# price           float64
# rating            int64
# availability     object
# category         object
# image            object
# dtype: object
#                                                title  price  rating  \
# 0                            It's Only the Himalayas  45.17       2
# 1  Full Moon over Noahâs Ark: An Odyssey to Mou...  49.43       4
# 2  See America: A Celebration of Our National Par...  48.87       3
# 3  Vagabonding: An Uncommon Guide to the Art of L...  36.94       2
# 4                               Under the Tuscan Sun  37.33       3
#
#   availability category                                              image
# 0     In stock   Travel  https://books.toscrape.com/media/cache/27/a5/2...
# 1     In stock   Travel  https://books.toscrape.com/media/cache/57/77/5...
# 2     In stock   Travel  https://books.toscrape.com/media/cache/9a/7e/9...
# 3     In stock   Travel  https://books.toscrape.com/media/cache/d5/bf/d...
# 4     In stock   Travel  https://books.toscrape.com/media/cache/98/c2/9...

# %%
base_livros['category'].apply(lambda x: len(x)).max()
# Out:
# np.int64(18)

# %%
base_livros.rating.value_counts()
# Out:
# rating
# 1    226
# 3    203
# 2    196
# 5    196
# 4    179
# Name: count, dtype: int64

# %%
base_livros.category.value_counts()
# Out:
# category
# Default               152
# Nonfiction            110
# Sequential Art         75
# Add a comment          67
# Fiction                65
# Young Adult            54
# Fantasy                48
# Romance                35
# Mystery                32
# Food and Drink         30
# Childrens              29
# Historical Fiction     26
# Classics               19
# Poetry                 19
# History                18
# Womens Fiction         17
# Horror                 17
# Science Fiction        16
# Science                14
# Music                  13
# Business               12
# Travel                 11
# Philosophy             11
# Thriller               11
# Humor                  10
# Autobiography           9
# Art                     8
# Religion                7
# Psychology              7
# Christian Fiction       6
# Spirituality            6
# New Adult               6
# Sports and Games        5
# Biography               5
# Self Help               5
# Health                  4
# Politics                3
# Contemporary            3
# Christian               3
# Historical              2
# Paranormal              1
# Parenting               1
# Adult Fiction           1
# Academic                1
# Short Stories           1
# Suspense                1
# Novels                  1
# Cultural                1
# Erotica                 1
# Crime                   1
# Name: count, dtype: int64

# %% [markdown]
# ## Exibindo as imagens

# %%
display(Image(url=base_livros.image[0]))
# Out:
# <img src="https://books.toscrape.com/media/cache/27/a5/27a53d0bb95bdd88288eaf66c9230d7e.jpg"/>
